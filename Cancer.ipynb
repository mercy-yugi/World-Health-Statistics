# %%
import pandas as pd
work_force=pd.read_csv("/home/student/Documents/World_Health_Organization_Statistics/cfafrica-_-data-team-_-outbreak-_-covid19-_-data-_-openafrica-uploads-_-kenya-healthworkers.csv")
work_force
# Out:
#              County  Core health workforce per 10,000\rpopulation
# 0           Baringo                                          10.6
# 1             Bomet                                           8.9
# 2           Bungoma                                           8.5
# 3             Busia                                          11.9
# 4   Elgeyo-marakwet                                           9.9
# 5              Embu                                          21.2
# 6           Garissa                                          10.0
# 7          Homa bay                                          14.2
# 8            Isiolo                                          22.0
# 9           Kajiado                                          24.6
# 10         Kakamega                                           9.9
# 11          Kericho                                          16.2
# 12           Kiambu                                          22.8
# ...

# %% [markdown]
# Checking the content of the data set so as to identify the null values.

# %%
work_force.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   County                                       48 non-null     object
# population  48 non-null     float6400
# dtypes: float64(1), object(1)
# memory usage: 896.0+ bytes

# %% [markdown]
# Defining the different data types of the output files.

# %%
work_force.describe()
# Out:
#        Core health workforce per 10,000\rpopulation
# count                                     48.000000
# mean                                      15.006250
# std                                        6.972237
# min                                        5.200000
# 25%                                        9.750000
# 50%                                       13.550000
# 75%                                       19.225000
# max                                       33.800000

# %%
# checking which columns has missing values. The additional functions helps in giving the additional information(percentages) on the columns with mising values.
work_force.apply(pd.isnull).sum()/work_force.shape[0]
# Out:
# County                                          0.0
# Core health workforce per 10,000\rpopulation    0.0
# dtype: float64

# %%
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# !pip install geopandas

# %%
df1 = work_force.sort_values(by = ['Core health workforce per 10,000\rpopulation'],ascending = False).reset_index()

Rates= px.bar(df1, x = 'County', y = 'Core health workforce per 10,000\rpopulation',
             color_continuous_scale = 'oranges')

Rates.update_layout(title = 'Core health workforce per 10,000\rpopulation vs County',
                  title_x = 0.5,
                  title_font = dict(size = 18, color = 'Green'))
Rates.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb Cell 9 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> Rates= px.bar(df1, x = 'County', y = 'Core health workforce per 10,000\rpopulation',
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a>              color_continuous_scale = 'oranges')
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> Rates.update_layout(title = 'Core health workforce per 10,000\rpopulation vs County',
# ...

# %%
# !pip install nbformat>=4.2.0

# %%
df1 = work_force.sort_values(by = ['Core health workforce per 10,000\rpopulation'],ascending = False).reset_index()

Rates= px.bar(df1, x = 'County', y = 'Core health workforce per 10,000\rpopulation',
             color_continuous_scale = 'oranges')

Rates.update_layout(title = 'Core health workforce per 10,000\rpopulation vs County',
                  title_x = 0.5,
                  title_font = dict(size = 18, color = 'Green'))
Rates.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb Cell 11 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> Rates= px.bar(df1, x = 'County', y = 'Core health workforce per 10,000\rpopulation',
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>              color_continuous_scale = 'oranges')
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> Rates.update_layout(title = 'Core health workforce per 10,000\rpopulation vs County',
# ...

# %%
pip install --upgrade nbformat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pip-22.2.2-py3-none-any.whl (2.0 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.1.2
#     Uninstalling pip-22.1.2:
#       Successfully uninstalled pip-22.1.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = work_force.sort_values(by = ['Core health workforce per 10,000\rpopulation'],ascending = False).reset_index()

Rates= px.bar(df1, x = 'County', y = 'Core health workforce per 10,000\rpopulation',
             color_continuous_scale = 'oranges')

Rates.update_layout(title = 'Core health workforce per 10,000\rpopulation vs County',
                  title_x = 0.5,
                  title_font = dict(size = 18, color = 'Green'))
Rates.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb Cell 14 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> Rates= px.bar(df1, x = 'County', y = 'Core health workforce per 10,000\rpopulation',
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>              color_continuous_scale = 'oranges')
#       <a href='vscode-notebook-cell:/home/student/Documents/World_Health_Organization_Statistics/Cancer.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> Rates.update_layout(title = 'Core health workforce per 10,000\rpopulation vs County',
# ...
